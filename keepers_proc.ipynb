# %%
import pandas as pd

# %%
keepers = pd.read_csv('data/league/FantraxDraftResults_Believers in BABIP (BIB).csv')

# %%
keepers = keepers[ keepers["Player ID"] != "*"]
keepers = keepers[["Player ID", "Player", "Round", "Pos", "Fantasy Team"]]
keepers.rename(columns = {"Player ID": "ID"}, inplace = True)
keepers.to_csv("data/proc/league_keeper_list.csv", index=False)

# %%
keepers.groupby("Fantasy Team").count()
# Out:
#                       ID  Player  Round  Pos
# Fantasy Team
# 99 prob pitch aint 1  10      10     10   10
# Bajanda                7       7      7    7
# Canha Get a Win?       9       9      9    9
# Freeman                7       7      7    7
# La Maquinaria          7       7      7    7
# Lindor sucks !!!       7       7      7    7
# Pequenos Campeones     6       6      6    6
# Pinstripes Pride      10      10     10   10
# SLGiantSLG            10      10     10   10
# Scavengers             4       4      4    4
# Trader Joey's         10      10     10   10
# We are the champions   7       7      7    7

# %%
keepers.groupby(["Fantasy Team", "Pos"]).count()
# Out:
#                           ID  Player  Round
# Fantasy Team         Pos
# 99 prob pitch aint 1 2B    1       1      1
#                      3B    1       1      1
#                      OF    2       2      2
#                      SP    5       5      5
#                      UT    1       1      1
# Bajanda              3B    2       2      2
#                      C     1       1      1
#                      OF    2       2      2
#                      SP    2       2      2
# Canha Get a Win?     1B    1       1      1
#                      OF    4       4      4
#                      RP    1       1      1
#                      SP    2       2      2
#                      SS    1       1      1
# Freeman              1B    1       1      1
#                      OF    1       1      1
#                      RP    2       2      2
#                      SP    2       2      2
#                      SS    1       1      1
# La Maquinaria        1B    1       1      1
# ...
